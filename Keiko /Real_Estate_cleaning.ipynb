# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#import csv
real_estate_file = 'data/nyc-rolling-sales.csv'
real_estate_df = pd.read_csv(real_estate_file)
real_estate_df.sample(5)

# %%
borough_name = []


for b in real_estate_df['BOROUGH']:
    if  b == 1:
        borough_name.append("Manhattan")
        
    elif b == 2:
        borough_name.append("Bronx") 
        
    elif b == 3: 
        borough_name.append("Brooklyn") 
        
    elif b == 4:
        borough_name.append("Queens")
        
    else:
        borough_name.append("Staten Island") 
        

real_estate_df["borough_name"] = borough_name
real_estate_df.sample(10)
# Out:
#        Unnamed: 0  BOROUGH             NEIGHBORHOOD  \
# 48281       22930        3       WILLIAMSBURG-NORTH
# 26477        1126        3       BEDFORD STUYVESANT
# 10974       10978        1              SOUTHBRIDGE
# 24430        6128        2              THROGS NECK
# 40732       15381        3               GREENPOINT
# 13578       13582        1  UPPER EAST SIDE (79-96)
# 31169        5818        3              BROWNSVILLE
# 35082        9731        3            CYPRESS HILLS
# 11465       11469        1                  TRIBECA
# 64584       15186        4                  JAMAICA
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 48281  03 THREE FAMILY DWELLINGS                                      1
# 26477  01 ONE FAMILY DWELLINGS                                        1
# 10974  13 CONDOS - ELEVATOR APARTMENTS                                2
# 24430  06 TAX CLASS 1 - OTHER                                         1
# 40732  04 TAX CLASS 1 CONDOS                                         1C
# 13578  10 COOPS - ELEVATOR APARTMENTS                                 2
# 31169  02 TWO FAMILY DWELLINGS                                        1
# 35082  03 THREE FAMILY DWELLINGS                                      1
# 11465  13 CONDOS - ELEVATOR APARTMENTS                                2
# 64584  02 TWO FAMILY DWELLINGS                                        1
#
#        BLOCK   LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 48281   2323    53                                  C0
# 26477   1667    38                                  A9
# 10974     90  1204                                  R4
# 24430   5591     2                                  G0
# 40732   2680  1003                                  R6
# 13578   1491     1                                  D4
# 31169   3585   125                                  B1
# 35082   4124     6                                  C0
# 11465    190  1515                                  R4
# 64584   9764   117                                  B1
#
#                       ADDRESS  ... COMMERCIAL UNITS  TOTAL UNITS  \
# 48281  295 NORTH 7TH   STREET  ...                0            3
# 26477       676 HALSEY STREET  ...                0            1
# 10974        5 BEEKMAN STREET  ...                0            1
# 24430       2828 MILES AVENUE  ...                0            0
# 40732      541 LEONARD STREET  ...                0            1
# 13578  980 FIFTH AVENUE, 22-B  ...                0            0
# 31169        339 HERZL STREET  ...                0            2
# 35082      165 NORWOOD AVENUE  ...                0            3
# 11465       124 HUDSON STREET  ...                0            1
# 64584    87-23 160TH   STREET  ...                0            2
#
#        LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  \
# 48281              1900               2850        1899
# 26477              2500               1076        1899
# 10974               -                  -          2016
# 24430              2696                  0           0
# 40732                 0                  0        1931
# 13578               -                  -          1966
# 31169              1000               2250        2005
# 35082              3113               3372        1901
# 11465               -                  -             0
# 64584              2352               2332        1910
#
#       TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  SALE PRICE  \
# 48281                         1                             C0     1850000
# 26477                         1                             A9           0
# 10974                         2                             R4     1700000
# 24430                         1                             G0           0
# 40732                         1                             R6     2550000
# 13578                         2                             D4     2600000
# 31169                         1                             B1           0
# 35082                         1                             C0           0
# 11465                         2                             R4     4650000
# 64584                         1                             B1      400000
#
#                  SALE DATE borough_name
# 48281  2017-04-25 00:00:00     Brooklyn
# 26477  2017-08-15 00:00:00     Brooklyn
# 10974  2016-10-11 00:00:00    Manhattan
# 24430  2017-03-21 00:00:00        Bronx
# 40732  2017-06-30 00:00:00     Brooklyn
# 13578  2017-02-09 00:00:00    Manhattan
# 31169  2017-06-15 00:00:00     Brooklyn
# 35082  2016-09-19 00:00:00     Brooklyn
# 11465  2017-08-17 00:00:00    Manhattan
# 64584  2017-01-06 00:00:00       Queens
#
# [10 rows x 23 columns]

# %%
#picking columns and assigning to new dataframe
real_estate_cols = ['BOROUGH', 'BLOCK', 'LOT', 'NEIGHBORHOOD', 'TAX CLASS AT PRESENT', 'ADDRESS',
                   'ZIP CODE', 'SALE PRICE', 'BUILDING CLASS AT TIME OF SALE', 'borough_name']

real_estate_clean_df = real_estate_df[real_estate_cols]


real_estate_clean_df.sample(5)
# Out:
#        BOROUGH  BLOCK   LOT    NEIGHBORHOOD TAX CLASS AT PRESENT  \
# 7576         1   1328    21    MIDTOWN EAST                    2
# 84411        5   1965  1153     WILLOWBROOK                    4
# 32490        3   8141    24        CANARSIE                    1
# 70853        4   3611    14       RIDGEWOOD                    1
# 58196        4   5048  1121  FLUSHING-NORTH                    2
#
#                         ADDRESS  ZIP CODE SALE PRICE  \
# 7576   245 EAST 54TH STREET, 4T     10022     418000
# 84411     1235 FOREST HILL ROAD     10314        -
# 32490        1029 REMSEN AVENUE     11236     425000
# 70853       61-18 LINDEN STREET     11385        -
# 58196                4107 BOWNE     11355         10
#
#       BUILDING CLASS AT TIME OF SALE   borough_name
# 7576                              D4      Manhattan
# 84411                             RG  Staten Island
# 32490                             B2       Brooklyn
# 70853                             B1         Queens
# 58196                             R4         Queens

# %%
# #import requests to get lat long for each address
# import requests

# response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA')

# resp_json_payload = response.json()

# print(resp_json_payload['results'][0]['geometry']['location'])
