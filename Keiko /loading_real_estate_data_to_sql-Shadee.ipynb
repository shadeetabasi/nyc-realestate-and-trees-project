# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#loaded CSV
real_estate ="data/nyc_real_estate_building_final_use_this.csv"
real_estate_df = pd.read_csv(real_estate)
real_estate_df.head()
# Out:
#    index                 full_address  \
# 0      0  ****** 95TH   STREET Queens
# 1      2         1 5 AVENUE Manhattan
# 2      3       1 5TH AVENUE Manhattan
# 3      4           1 ASCAN AVE Queens
# 4      5        1 ASCAN AVENUE Queens
#
#                        building_class_category  sale_price  \
# 0  07 RENTALS - WALKUP APARTMENTS                      0.0
# 1  07 RENTALS - WALKUP APARTMENTS                4925000.0
# 2  07 RENTALS - WALKUP APARTMENTS                      0.0
# 3  07 RENTALS - WALKUP APARTMENTS                 649000.0
# 4  07 RENTALS - WALKUP APARTMENTS                 395000.0
#
#                 neighborhood tax_class_at_present  zip_code  \
# 0                 OZONE PARK                   1B   11417.0
# 1  GREENWICH VILLAGE-CENTRAL                    2   10003.0
# 2  GREENWICH VILLAGE-CENTRAL                    2   10003.0
# 3               FOREST HILLS                    2   11375.0
# 4               FOREST HILLS                    2   11375.0
#
#   building_class_at_time_of_sale borough_name   latitude  longitude
# 0                             V0       Queens  40.686989 -73.847231
# 1                             D4    Manhattan  49.836689  24.020745
# 2                             D4    Manhattan  40.745898 -73.986688
# 3                             D4       Queens  40.717455 -73.841313
# 4                             D4       Queens  40.717455 -73.841313

# %%
real_estate_df = real_estate_df.rename(columns={"Full_Address": "full_address",
                                               "BUILDING CLASS CATEGORY": "building_class_category",
                                               "SALE PRICE": "sale_price",
                                               "NEIGHBORHOOD": "neighborhood",
                                               "TAX CLASS AT PRESENT": "tax_class_at_present",
                                               "ZIP CODE": "zip_code",
                                               "BUILDING CLASS AT TIME OF SALE": "building_class_at_time_of_sale",
                                               "borough_name": "borough_name",
                                               "latitude": "latitude",
                                               "longitude": "longitude"})

real_estate_df.head()
# Out:
#    index                 full_address  \
# 0      0  ****** 95TH   STREET Queens
# 1      2         1 5 AVENUE Manhattan
# 2      3       1 5TH AVENUE Manhattan
# 3      4           1 ASCAN AVE Queens
# 4      5        1 ASCAN AVENUE Queens
#
#                        building_class_category  sale_price  \
# 0  07 RENTALS - WALKUP APARTMENTS                      0.0
# 1  07 RENTALS - WALKUP APARTMENTS                4925000.0
# 2  07 RENTALS - WALKUP APARTMENTS                      0.0
# 3  07 RENTALS - WALKUP APARTMENTS                 649000.0
# 4  07 RENTALS - WALKUP APARTMENTS                 395000.0
#
#                 neighborhood tax_class_at_present  zip_code  \
# 0                 OZONE PARK                   1B   11417.0
# 1  GREENWICH VILLAGE-CENTRAL                    2   10003.0
# 2  GREENWICH VILLAGE-CENTRAL                    2   10003.0
# 3               FOREST HILLS                    2   11375.0
# 4               FOREST HILLS                    2   11375.0
#
#   building_class_at_time_of_sale borough_name   latitude  longitude
# 0                             V0       Queens  40.686989 -73.847231
# 1                             D4    Manhattan  49.836689  24.020745
# 2                             D4    Manhattan  40.745898 -73.986688
# 3                             D4       Queens  40.717455 -73.841313
# 4                             D4       Queens  40.717455 -73.841313

# %%
#connect engine
###note to group, update local host location and name of database to reflect what is on your system
connection_string = "postgres:postgres@localhost:5432/group_project_2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
#checking tables names 
engine.table_names()
# Out:
# ['new_york_tree_census_data',
#  'real_estate_data',
#  'real_estate_data_final',
#  'new_york_tree_census_data_final']

# %%
#Reset index name to load into SQL database
real_estate_df.index.name = "id"

# %%
clean_real_estate_df = real_estate_df.drop(['index'], axis=1)

# %%
clean_real_estate_df
# Out:
#                       full_address  \
# id
# 0      ****** 95TH   STREET Queens
# 1             1 5 AVENUE Manhattan
# 2           1 5TH AVENUE Manhattan
# 3               1 ASCAN AVE Queens
# 4            1 ASCAN AVENUE Queens
# ...                            ...
# 55737   WOODROW ROAD Staten Island
# 55738      WOODYCREST AVENUE Bronx
# 55739      WORTMAN AVENUE Brooklyn
# 55740    YORK AVENUE Staten Island
# 55741          ZEREGA AVENUE Bronx
#
#                            building_class_category  sale_price  \
# id
# 0      07 RENTALS - WALKUP APARTMENTS                      0.0
# 1      07 RENTALS - WALKUP APARTMENTS                4925000.0
# 2      07 RENTALS - WALKUP APARTMENTS                      0.0
# 3      07 RENTALS - WALKUP APARTMENTS                 649000.0
# 4      07 RENTALS - WALKUP APARTMENTS                 395000.0
# ...                                            ...         ...
# 55737  13 CONDOS - ELEVATOR APARTMENTS                     0.0
# 55738  13 CONDOS - ELEVATOR APARTMENTS                750000.0
# 55739  13 CONDOS - ELEVATOR APARTMENTS                     0.0
# 55740  13 CONDOS - ELEVATOR APARTMENTS                235000.0
# 55741  13 CONDOS - ELEVATOR APARTMENTS               5000000.0
#
#                     neighborhood tax_class_at_present  zip_code  \
# id
# 0                     OZONE PARK                   1B   11417.0
# 1      GREENWICH VILLAGE-CENTRAL                    2   10003.0
# 2      GREENWICH VILLAGE-CENTRAL                    2   10003.0
# 3                   FOREST HILLS                    2   11375.0
# 4                   FOREST HILLS                    2   11375.0
# ...                          ...                  ...       ...
# 55737              ARDEN HEIGHTS                   1B   10312.0
# 55738  HIGHBRIDGE/MORRIS HEIGHTS                    4       0.0
# 55739              EAST NEW YORK                    4       0.0
# 55740               NEW BRIGHTON                   1B   10301.0
# 55741      CASTLE HILL/UNIONPORT                    4   10473.0
#
#       building_class_at_time_of_sale   borough_name   latitude  longitude
# id
# 0                                 V0         Queens  40.686989 -73.847231
# 1                                 D4      Manhattan  49.836689  24.020745
# 2                                 D4      Manhattan  40.745898 -73.986688
# 3                                 D4         Queens  40.717455 -73.841313
# 4                                 D4         Queens  40.717455 -73.841313
# ...                              ...            ...        ...        ...
# 55737                             V0  Staten Island  40.546672 -74.191896
# 55738                             G7          Bronx  40.830083 -73.929969
# 55739                             G7       Brooklyn  40.661459 -73.874470
# 55740                             V0  Staten Island  40.642265 -74.087684
# 55741                             V1          Bronx  40.836779 -73.846690
#
# [55742 rows x 10 columns]

# %%
#loading data to postgresSQL
clean_real_estate_df.to_sql(name='real_estate_data', con=engine, if_exists='append', index=True)
