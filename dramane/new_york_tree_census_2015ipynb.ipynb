# %%
import pandas as pd

# %%
new_york_tree_census_2015_dataset = "../dramane/new_york_tree_census_2015.csv"
new_york_tree_census_2015_df = pd.read_csv(new_york_tree_census_2015_dataset)
new_york_tree_census_2015_df.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   606945    305778  2016-06-28        10           0   OnCurb  Alive   Good
# 1   160321    341273  2015-08-19         9           0   OnCurb  Alive   Good
# 2   541347    325281  2015-12-30         7           0   OnCurb  Alive   Good
# 3   613930    203822  2016-07-05        10           0   OnCurb  Alive   Good
# 4    18353    338911  2015-06-13         4           0   OnCurb  Alive   Good
#
#                             spc_latin              spc_common  ... st_assem  \
# 0              Fraxinus pennsylvanica               green ash  ...       25
# 1  Gleditsia triacanthos var. inermis             honeylocust  ...       34
# 2                    Pyrus calleryana            Callery pear  ...       32
# 3                    Pyrus calleryana            Callery pear  ...       46
# 4                   Prunus virginiana  'Schubert' chokecherry  ...       31
#
#   st_senate   nta                  nta_name  boro_ct     state   latitude  \
# 0        14  QN37         Kew Gardens Hills  4125700  New York  40.724339
# 1        13  QN28           Jackson Heights  4030902  New York  40.756626
# 2        10  QN76              Baisley Park  4028800  New York  40.679777
# 3        22  BK31                 Bay Ridge  3005000  New York  40.622743
# 4        10  QN12  Hammels-Arverne-Edgemere  4095400  New York  40.596514
#
#    longitude          x_sp         y_sp
# 0 -73.805180  1.038250e+06  203232.9417
# 1 -73.894167  1.013571e+06  214953.6472
# 2 -73.788463  1.042923e+06  187008.2671
# 3 -74.037543  9.738279e+05  166160.5847
# 4 -73.797622  1.040452e+06  156667.5017
#
# [5 rows x 41 columns]

# %%
new_new_york_tree_census_2015_df = new_york_tree_census_2015_df[['tree_id', 'status', 'health', 'latitude', 'longitude', 'nta_name', 'boro_ct', 'spc_latin']]

new_new_york_tree_census_2015_df
# Out:
#         tree_id status health   latitude  longitude  \
# 0        606945  Alive   Good  40.724339 -73.805180
# 1        160321  Alive   Good  40.756626 -73.894167
# 2        541347  Alive   Good  40.679777 -73.788463
# 3        613930  Alive   Good  40.622743 -74.037543
# 4         18353  Alive   Good  40.596514 -73.797622
# ...         ...    ...    ...        ...        ...
# 683783   237788  Alive   Poor  40.672566 -74.011473
# 683784   249489   Dead    NaN  40.730434 -73.710600
# 683785   230261   Dead    NaN  40.633890 -73.969779
# 683786   623784  Alive   Good  40.676190 -73.813135
# 683787   139749  Alive   Good  40.712328 -73.959385
#
#                                         nta_name  boro_ct  \
# 0                              Kew Gardens Hills  4125700
# 1                                Jackson Heights  4030902
# 2                                   Baisley Park  4028800
# 3                                      Bay Ridge  3005000
# 4                       Hammels-Arverne-Edgemere  4095400
# ...                                          ...      ...
# 683783  Carroll Gardens-Columbia Street-Red Hook  3005300
# 683784       Glen Oaks-Floral Park-New Hyde Park  4157903
# 683785                                  Flatbush  3048200
# 683786                          South Ozone Park  4017800
# 683787                     North Side-South Side  3052300
#
#                                  spc_latin
# 0                   Fraxinus pennsylvanica
# 1       Gleditsia triacanthos var. inermis
# 2                         Pyrus calleryana
# 3                         Pyrus calleryana
# 4                        Prunus virginiana
# ...                                    ...
# 683783                   Prunus cerasifera
# 683784                                 NaN
# 683785                                 NaN
# 683786                       Quercus rubra
# 683787                     Zelkova serrata
#
# [683788 rows x 8 columns]

# %%
new_new_york_tree_census_2015_df['spc_latin_for_join']=new_new_york_tree_census_2015_df['spc_latin'].str.strip()

new_new_york_tree_census_2015_df['spc_latin_for_join']=new_new_york_tree_census_2015_df['spc_latin_for_join'].str.replace(" ",'')
new_new_york_tree_census_2015_df['spc_latin_for_join']=new_new_york_tree_census_2015_df['spc_latin_for_join'].str.lower()
new_new_york_tree_census_2015_df.sample(10)
# Out:
# <ipython-input-12-e14aac06183a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_new_york_tree_census_2015_df['spc_latin_for_join']=new_new_york_tree_census_2015_df['spc_latin'].str.strip()
# <ipython-input-12-e14aac06183a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_new_york_tree_census_2015_df['spc_latin_for_join']=new_new_york_tree_census_2015_df['spc_latin_for_join'].str.replace(" ",'')
# <ipython-input-12-e14aac06183a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_new_york_tree_census_2015_df['spc_latin_for_join']=new_new_york_tree_census_2015_df['spc_latin_for_join'].str.lower()
#         tree_id status health   latitude  longitude  \
# 282229   396425  Alive   Good  40.714472 -73.983866
# 621077   699187  Alive   Good  40.655668 -73.927960
# 226153   602531  Alive   Fair  40.784871 -73.809102
# 413960   403172  Stump    NaN  40.540685 -74.195601
# 494119   543289  Alive   Good  40.872876 -73.833811
# 541734    78686  Alive   Good  40.678142 -73.991140
# 530312   403754  Alive   Good  40.608325 -73.944466
# 403777   404837  Alive   Good  40.730443 -73.758498
# 567650   629491  Alive   Good  40.718557 -73.870773
# 237546   529176  Alive   Good  40.771990 -73.981778
#
#                                         nta_name  boro_ct  \
# 282229                           Lower East Side  1000202
# 621077                      Rugby-Remsen Village  3086800
# 226153                                Whitestone  4102900
# 413960                             Arden Heights  5017009
# 494119                                Co-op City  2046201
# 541734  Carroll Gardens-Columbia Street-Red Hook  3007700
# 530312                                   Madison  3056400
# 403777                           Oakland Gardens  4129102
# 567650                            Middle Village  4067700
# 237546                            Lincoln Square  1014900
#
#                                  spc_latin               spc_latin_for_join
# 282229  Gleditsia triacanthos var. inermis  gleditsiatriacanthosvar.inermis
# 621077                    Acer platanoides                  acerplatanoides
# 226153                    Pyrus calleryana                  pyruscalleryana
# 413960                                 NaN                              NaN
# 494119                               Malus                            malus
# 541734                         Acer rubrum                       acerrubrum
# 530312                     Zelkova serrata                   zelkovaserrata
# 403777                  Syringa reticulata                syringareticulata
# 567650  Gleditsia triacanthos var. inermis  gleditsiatriacanthosvar.inermis
# 237546                    Pyrus calleryana                  pyruscalleryana

# %%
chars = "\`*_{}[]()>#+-.,!$:;%'&/?"
for c in chars:
    new_new_york_tree_census_2015_df['spc_latin_for_join'] = new_new_york_tree_census_2015_df['spc_latin_for_join'].str.replace(c,"")

new_new_york_tree_census_2015_df
# Out:
# <ipython-input-13-1758ca78d1d1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_new_york_tree_census_2015_df['spc_latin_for_join'] = new_new_york_tree_census_2015_df['spc_latin_for_join'].str.replace(c,"")
#         tree_id status health   latitude  longitude  \
# 0        606945  Alive   Good  40.724339 -73.805180
# 1        160321  Alive   Good  40.756626 -73.894167
# 2        541347  Alive   Good  40.679777 -73.788463
# 3        613930  Alive   Good  40.622743 -74.037543
# 4         18353  Alive   Good  40.596514 -73.797622
# ...         ...    ...    ...        ...        ...
# 683783   237788  Alive   Poor  40.672566 -74.011473
# 683784   249489   Dead    NaN  40.730434 -73.710600
# 683785   230261   Dead    NaN  40.633890 -73.969779
# 683786   623784  Alive   Good  40.676190 -73.813135
# 683787   139749  Alive   Good  40.712328 -73.959385
#
#                                         nta_name  boro_ct  \
# 0                              Kew Gardens Hills  4125700
# 1                                Jackson Heights  4030902
# 2                                   Baisley Park  4028800
# 3                                      Bay Ridge  3005000
# 4                       Hammels-Arverne-Edgemere  4095400
# ...                                          ...      ...
# 683783  Carroll Gardens-Columbia Street-Red Hook  3005300
# 683784       Glen Oaks-Floral Park-New Hyde Park  4157903
# 683785                                  Flatbush  3048200
# 683786                          South Ozone Park  4017800
# 683787                     North Side-South Side  3052300
#
#                                  spc_latin              spc_latin_for_join
# 0                   Fraxinus pennsylvanica           fraxinuspennsylvanica
# 1       Gleditsia triacanthos var. inermis  gleditsiatriacanthosvarinermis
# 2                         Pyrus calleryana                 pyruscalleryana
# 3                         Pyrus calleryana                 pyruscalleryana
# 4                        Prunus virginiana                prunusvirginiana
# ...                                    ...                             ...
# 683783                   Prunus cerasifera                prunuscerasifera
# 683784                                 NaN                             NaN
# 683785                                 NaN                             NaN
# 683786                       Quercus rubra                    quercusrubra
# 683787                     Zelkova serrata                  zelkovaserrata
#
# [683788 rows x 9 columns]

# %%
clean_new_york_tree_census_2015_df = new_new_york_tree_census_2015_df.drop_duplicates()
clean_new_york_tree_census_2015_df.head(20)
# Out:
#     tree_id  block_id status health                           spc_latin  \
# 0    606945    305778  Alive   Good              Fraxinus pennsylvanica
# 1    160321    341273  Alive   Good  Gleditsia triacanthos var. inermis
# 2    541347    325281  Alive   Good                    Pyrus calleryana
# 3    613930    203822  Alive   Good                    Pyrus calleryana
# 4     18353    338911  Alive   Good                   Prunus virginiana
# 5     21173    108713  Alive   Good  Gleditsia triacanthos var. inermis
# 6    544698    201434  Alive   Fair                       Quercus rubra
# 7    546240    228778  Alive   Good                     Tilia americana
# 8    646348    309729  Alive   Good                   Quercus palustris
# 9    413812    501196  Alive   Good                     Ulmus americana
# 10   643898    308820  Alive   Good               Platanus x acerifolia
# 11    51527    414908  Alive   Good                    Pyrus calleryana
# 12   111516    103671  Alive   Good                     Tilia americana
# 13   316742    413488  Alive   Good                    Acer saccharinum
# 14   428425    222536   Dead    NaN                                 NaN
# 15   581674    330418  Alive   Good  Gleditsia triacanthos var. inermis
# 16   341736    510883   Dead    NaN                                 NaN
# 17   545989    212884  Alive   Good                  Fraxinus americana
# 18   386593    400007  Alive   Fair                       Quercus rubra
# 19    10288    219608  Alive   Fair                           Crataegus
#
#                 spc_latin_for_join
# 0            fraxinuspennsylvanica
# 1   gleditsiatriacanthosvarinermis
# 2                  pyruscalleryana
# 3                  pyruscalleryana
# 4                 prunusvirginiana
# 5   gleditsiatriacanthosvarinermis
# 6                     quercusrubra
# 7                   tiliaamericana
# 8                 quercuspalustris
# 9                   ulmusamericana
# 10             platanusxacerifolia
# 11                 pyruscalleryana
# 12                  tiliaamericana
# 13                 acersaccharinum
# 14                             NaN
# 15  gleditsiatriacanthosvarinermis
# 16                             NaN
# 17               fraxinusamericana
# 18                    quercusrubra
# 19                       crataegus

# %%
clean_new_york_tree_census_2015_df.to_csv(r'../dramane/clean_new_york_tree_census_2015_data.csv', index = False)
