# %%
import pandas as pd

# %%
new_york_tree_census_2015_dataset = "new_york_tree_census_2015.csv"
new_york_tree_census_2015_df = pd.read_csv(new_york_tree_census_2015_dataset)
new_york_tree_census_2015_df.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   606945    305778  2016-06-28        10           0   OnCurb  Alive   Good
# 1   160321    341273  2015-08-19         9           0   OnCurb  Alive   Good
# 2   541347    325281  2015-12-30         7           0   OnCurb  Alive   Good
# 3   613930    203822  2016-07-05        10           0   OnCurb  Alive   Good
# 4    18353    338911  2015-06-13         4           0   OnCurb  Alive   Good
#
#                             spc_latin              spc_common  ... st_assem  \
# 0              Fraxinus pennsylvanica               green ash  ...       25
# 1  Gleditsia triacanthos var. inermis             honeylocust  ...       34
# 2                    Pyrus calleryana            Callery pear  ...       32
# 3                    Pyrus calleryana            Callery pear  ...       46
# 4                   Prunus virginiana  'Schubert' chokecherry  ...       31
#
#   st_senate   nta                  nta_name  boro_ct     state   latitude  \
# 0        14  QN37         Kew Gardens Hills  4125700  New York  40.724339
# 1        13  QN28           Jackson Heights  4030902  New York  40.756626
# 2        10  QN76              Baisley Park  4028800  New York  40.679777
# 3        22  BK31                 Bay Ridge  3005000  New York  40.622743
# 4        10  QN12  Hammels-Arverne-Edgemere  4095400  New York  40.596514
#
#    longitude          x_sp         y_sp
# 0 -73.805180  1.038250e+06  203232.9417
# 1 -73.894167  1.013571e+06  214953.6472
# 2 -73.788463  1.042923e+06  187008.2671
# 3 -74.037543  9.738279e+05  166160.5847
# 4 -73.797622  1.040452e+06  156667.5017
#
# [5 rows x 41 columns]

# %%
new_new_york_tree_census_2015_df = new_york_tree_census_2015_df[['tree_id', 'stump_diam', 'status', 'health', 'spc_latin', 'spc_common', 'address', 'zipcode', 'boroname', 'nta_name', 'latitude', 'longitude']].copy()

new_new_york_tree_census_2015_df
# Out:
#         tree_id  stump_diam status health                           spc_latin  \
# 0        606945           0  Alive   Good              Fraxinus pennsylvanica
# 1        160321           0  Alive   Good  Gleditsia triacanthos var. inermis
# 2        541347           0  Alive   Good                    Pyrus calleryana
# 3        613930           0  Alive   Good                    Pyrus calleryana
# 4         18353           0  Alive   Good                   Prunus virginiana
# ...         ...         ...    ...    ...                                 ...
# 683783   237788           0  Alive   Poor                   Prunus cerasifera
# 683784   249489           0   Dead    NaN                                 NaN
# 683785   230261           0   Dead    NaN                                 NaN
# 683786   623784           0  Alive   Good                       Quercus rubra
# 683787   139749           0  Alive   Good                     Zelkova serrata
#
#                     spc_common                     address  zipcode  boroname  \
# 0                    green ash           76-046 164 STREET    11366    Queens
# 1                  honeylocust            72-020 32 AVENUE    11370    Queens
# 2                 Callery pear          153-026 119 AVENUE    11434    Queens
# 3                 Callery pear                89 89 STREET    11209  Brooklyn
# 4       'Schubert' chokecherry         559 BEACH 68 STREET    11692    Queens
# ...                        ...                         ...      ...       ...
# 683783        purple-leaf plum              1 BEARD STREET    11231  Brooklyn
# 683784                     NaN  87-015 LITTLE NECK PARKWAY    11001    Queens
# 683785                     NaN           644 EAST 8 STREET    11230  Brooklyn
# 683786        northern red oak          116-019 125 STREET    11420    Queens
# 683787        Japanese zelkova          209 SOUTH 2 STREET    11211  Brooklyn
#
#                                         nta_name   latitude  longitude
# 0                              Kew Gardens Hills  40.724339 -73.805180
# 1                                Jackson Heights  40.756626 -73.894167
# 2                                   Baisley Park  40.679777 -73.788463
# 3                                      Bay Ridge  40.622743 -74.037543
# 4                       Hammels-Arverne-Edgemere  40.596514 -73.797622
# ...                                          ...        ...        ...
# 683783  Carroll Gardens-Columbia Street-Red Hook  40.672566 -74.011473
# 683784       Glen Oaks-Floral Park-New Hyde Park  40.730434 -73.710600
# 683785                                  Flatbush  40.633890 -73.969779
# 683786                          South Ozone Park  40.676190 -73.813135
# 683787                     North Side-South Side  40.712328 -73.959385
#
# [683788 rows x 12 columns]

# %%
new_new_york_tree_census_2015_df['spc_latin_for_join']=new_new_york_tree_census_2015_df['spc_latin'].str.strip().copy()
new_new_york_tree_census_2015_df['spc_latin_for_join']=new_new_york_tree_census_2015_df['spc_latin_for_join'].str.replace(" ",'').copy()
new_new_york_tree_census_2015_df['spc_latin_for_join']=new_new_york_tree_census_2015_df['spc_latin_for_join'].str.lower().copy()
new_new_york_tree_census_2015_df.sample(10)
# Out:
#         tree_id  stump_diam status health              spc_latin  \
# 532458   672959           0  Alive   Good       Acer platanoides
# 348471   100429           0  Alive   Fair  Platanus x acerifolia
# 679568   274362           0  Alive   Good                 Prunus
# 220586   111468           0  Alive   Good       Pyrus calleryana
# 64529    326659           0  Alive   Good        Ulmus americana
# 582509   227395           0  Alive   Good      Quercus palustris
# 246280   549333           0  Alive   Good          Ginkgo biloba
# 301004   356532           0  Alive   Good          Quercus robur
# 393530   425663           0  Alive   Good      Quercus palustris
# 50607    669023           0  Alive   Good        Tilia tomentosa
#
#               spc_common                      address  zipcode  boroname  \
# 532458      Norway maple            84-015 114 STREET    11418    Queens
# 348471  London planetree           392 DE GRAW STREET    11231  Brooklyn
# 679568            cherry   71-006 LITTLE NECK PARKWAY    11426    Queens
# 220586      Callery pear        36-046 BELL BOULEVARD    11361    Queens
# 64529       American elm               7507 10 AVENUE    11228  Brooklyn
# 582509           pin oak  88-028 WINCHESTER BOULEVARD    11427    Queens
# 246280            ginkgo              104 TROY AVENUE    11213  Brooklyn
# 301004       English oak        1240 EVERGREEN AVENUE    10472     Bronx
# 393530           pin oak           594 JAMAICA AVENUE    11208  Brooklyn
# 50607      silver linden           150-010 132 AVENUE    11434    Queens
#
#                                         nta_name   latitude  longitude  \
# 532458                             Richmond Hill  40.702182 -73.836311
# 348471  Carroll Gardens-Columbia Street-Red Hook  40.682423 -73.991961
# 679568       Glen Oaks-Floral Park-New Hyde Park  40.751511 -73.721063
# 220586                     Bayside-Bayside Hills  40.766521 -73.772898
# 64529                              Dyker Heights  40.624010 -74.014206
# 582509                                 Bellerose  40.729913 -73.736865
# 246280                       Crown Heights North  40.675427 -73.936527
# 301004                    West Farms-Bronx River  40.829848 -73.881313
# 393530                   Cypress Hills-City Line  40.686524 -73.883153
# 50607                  Springfield Gardens North  40.671340 -73.786123
#
#          spc_latin_for_join
# 532458      acerplatanoides
# 348471  platanusxacerifolia
# 679568               prunus
# 220586      pyruscalleryana
# 64529        ulmusamericana
# 582509     quercuspalustris
# 246280         ginkgobiloba
# 301004         quercusrobur
# 393530     quercuspalustris
# 50607        tiliatomentosa

# %%
chars = "\`*_{}[]()>#+-.,!$:;%'&/?"
for c in chars:
    new_new_york_tree_census_2015_df['spc_latin_for_join'] = new_new_york_tree_census_2015_df['spc_latin_for_join'].str.replace(c,"")

new_new_york_tree_census_2015_df
# Out:
#         tree_id  stump_diam status health                           spc_latin  \
# 0        606945           0  Alive   Good              Fraxinus pennsylvanica
# 1        160321           0  Alive   Good  Gleditsia triacanthos var. inermis
# 2        541347           0  Alive   Good                    Pyrus calleryana
# 3        613930           0  Alive   Good                    Pyrus calleryana
# 4         18353           0  Alive   Good                   Prunus virginiana
# ...         ...         ...    ...    ...                                 ...
# 683783   237788           0  Alive   Poor                   Prunus cerasifera
# 683784   249489           0   Dead    NaN                                 NaN
# 683785   230261           0   Dead    NaN                                 NaN
# 683786   623784           0  Alive   Good                       Quercus rubra
# 683787   139749           0  Alive   Good                     Zelkova serrata
#
#                     spc_common                     address  zipcode  boroname  \
# 0                    green ash           76-046 164 STREET    11366    Queens
# 1                  honeylocust            72-020 32 AVENUE    11370    Queens
# 2                 Callery pear          153-026 119 AVENUE    11434    Queens
# 3                 Callery pear                89 89 STREET    11209  Brooklyn
# 4       'Schubert' chokecherry         559 BEACH 68 STREET    11692    Queens
# ...                        ...                         ...      ...       ...
# 683783        purple-leaf plum              1 BEARD STREET    11231  Brooklyn
# 683784                     NaN  87-015 LITTLE NECK PARKWAY    11001    Queens
# 683785                     NaN           644 EAST 8 STREET    11230  Brooklyn
# 683786        northern red oak          116-019 125 STREET    11420    Queens
# 683787        Japanese zelkova          209 SOUTH 2 STREET    11211  Brooklyn
#
#                                         nta_name   latitude  longitude  \
# 0                              Kew Gardens Hills  40.724339 -73.805180
# 1                                Jackson Heights  40.756626 -73.894167
# 2                                   Baisley Park  40.679777 -73.788463
# 3                                      Bay Ridge  40.622743 -74.037543
# 4                       Hammels-Arverne-Edgemere  40.596514 -73.797622
# ...                                          ...        ...        ...
# 683783  Carroll Gardens-Columbia Street-Red Hook  40.672566 -74.011473
# 683784       Glen Oaks-Floral Park-New Hyde Park  40.730434 -73.710600
# 683785                                  Flatbush  40.633890 -73.969779
# 683786                          South Ozone Park  40.676190 -73.813135
# 683787                     North Side-South Side  40.712328 -73.959385
#
#                     spc_latin_for_join
# 0                fraxinuspennsylvanica
# 1       gleditsiatriacanthosvarinermis
# 2                      pyruscalleryana
# 3                      pyruscalleryana
# 4                     prunusvirginiana
# ...                                ...
# 683783                prunuscerasifera
# 683784                             NaN
# 683785                             NaN
# 683786                    quercusrubra
# 683787                  zelkovaserrata
#
# [683788 rows x 13 columns]

# %%
clean_new_york_tree_census_2015_df = new_new_york_tree_census_2015_df.drop_duplicates()
clean_new_york_tree_census_2015_df.head(20)
# Out:
#     tree_id  stump_diam status health                           spc_latin  \
# 0    606945           0  Alive   Good              Fraxinus pennsylvanica
# 1    160321           0  Alive   Good  Gleditsia triacanthos var. inermis
# 2    541347           0  Alive   Good                    Pyrus calleryana
# 3    613930           0  Alive   Good                    Pyrus calleryana
# 4     18353           0  Alive   Good                   Prunus virginiana
# 5     21173           0  Alive   Good  Gleditsia triacanthos var. inermis
# 6    544698           0  Alive   Fair                       Quercus rubra
# 7    546240           0  Alive   Good                     Tilia americana
# 8    646348           0  Alive   Good                   Quercus palustris
# 9    413812           0  Alive   Good                     Ulmus americana
# 10   643898           0  Alive   Good               Platanus x acerifolia
# 11    51527           0  Alive   Good                    Pyrus calleryana
# 12   111516           0  Alive   Good                     Tilia americana
# 13   316742           0  Alive   Good                    Acer saccharinum
# 14   428425           0   Dead    NaN                                 NaN
# 15   581674           0  Alive   Good  Gleditsia triacanthos var. inermis
# 16   341736           0   Dead    NaN                                 NaN
# 17   545989           0  Alive   Good                  Fraxinus americana
# 18   386593           0  Alive   Fair                       Quercus rubra
# 19    10288           0  Alive   Fair                           Crataegus
#
#                 spc_common                     address  zipcode  \
# 0                green ash           76-046 164 STREET    11366
# 1              honeylocust            72-020 32 AVENUE    11370
# 2             Callery pear          153-026 119 AVENUE    11434
# 3             Callery pear                89 89 STREET    11209
# 4   'Schubert' chokecherry         559 BEACH 68 STREET    11692
# 5              honeylocust               3554 BROADWAY    10031
# 6         northern red oak          2030 PITKIN AVENUE    11207
# 7          American linden    5008 FT HAMILTON PARKWAY    11219
# 8                  pin oak  85-006 WOODHAVEN BOULEVARD    11421
# 9             American elm        1340 EAST BAY AVENUE    10474
# 10        London planetree           97-016 116 STREET    11419
# 11            Callery pear           234 CORBIN AVENUE    10308
# 12         American linden               311 10 AVENUE    10001
# 13            silver maple             73 MACON AVENUE    10312
# 14                     NaN           176 SUYDAM STREET    11221
# 15             honeylocust   152-002 BAISLEY BOULEVARD    11434
# 16                     NaN      345 CITY ISLAND AVENUE    10464
# 17               white ash               3919 AVENUE P    11234
# 18        northern red oak             197 HOPE AVENUE    10305
# 19                hawthorn            283 ADAMS STREET    11201
#
#          boroname                                          nta_name  \
# 0          Queens                                 Kew Gardens Hills
# 1          Queens                                   Jackson Heights
# 2          Queens                                      Baisley Park
# 3        Brooklyn                                         Bay Ridge
# 4          Queens                          Hammels-Arverne-Edgemere
# 5       Manhattan                                  Hamilton Heights
# 6        Brooklyn                  East New York (Pennsylvania Ave)
# 7        Brooklyn                                      Borough Park
# 8          Queens                                         Woodhaven
# 9           Bronx                                       Hunts Point
# 10         Queens                                     Richmond Hill
# 11  Staten Island                                       Great Kills
# 12      Manhattan        Hudson Yards-Chelsea-Flatiron-Union Square
# 13  Staten Island        Annadale-Huguenot-Prince's Bay-Eltingville
# 14       Brooklyn                                    Bushwick South
# 15         Queens                         Springfield Gardens North
# 16          Bronx               Pelham Bay-Country Club-City Island
# 17       Brooklyn    Georgetown-Marine Park-Bergen Beach-Mill Basin
# 18  Staten Island                                Stapleton-Rosebank
# 19       Brooklyn  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
#
#      latitude  longitude              spc_latin_for_join
# 0   40.724339 -73.805180           fraxinuspennsylvanica
# 1   40.756626 -73.894167  gleditsiatriacanthosvarinermis
# 2   40.679777 -73.788463                 pyruscalleryana
# 3   40.622743 -74.037543                 pyruscalleryana
# 4   40.596514 -73.797622                prunusvirginiana
# 5   40.826887 -73.949889  gleditsiatriacanthosvarinermis
# 6   40.671347 -73.897614                    quercusrubra
# 7   40.637774 -73.998692                  tiliaamericana
# 8   40.696668 -73.853087                quercuspalustris
# 9   40.808967 -73.882647                  ulmusamericana
# 10  40.689988 -73.828948             platanusxacerifolia
# 11  40.561235 -74.147569                 pyruscalleryana
# 12  40.750503 -74.001265                  tiliaamericana
# 13  40.557400 -74.171932                 acersaccharinum
# 14  40.699655 -73.926053                             NaN
# 15  40.670216 -73.786138  gleditsiatriacanthosvarinermis
# 16  40.848221 -73.786963                             NaN
# 17  40.618049 -73.936002               fraxinusamericana
# 18  40.607726 -74.070159                    quercusrubra
# 19  40.694321 -73.988863                       crataegus

# %%
clean_new_york_tree_census_2015_df.to_csv(r'../dramane/clean_new_york_tree_census_2015_data.csv', index = False)

# %%
clean_new_york_tree_census_2015_df.dtypes
# Out:
# tree_id                 int64
# stump_diam              int64
# status                 object
# health                 object
# spc_latin              object
# spc_common             object
# address                object
# zipcode                 int64
# boroname               object
# nta_name               object
# latitude              float64
# longitude             float64
# spc_latin_for_join     object
# dtype: object

# %% [markdown]
# # Create Engine to Database Connection

# %%
#Setup and import dependencies
from sqlalchemy import create_engine
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
# Create Engine to Database
## Please note this is using Shadee's postgres password which is also postgres

connection_string = "postgres:postgres@localhost:5432/group_project_2"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['new_york_tree_census_data', 'new_york_tree_census_data_final']

# %% [markdown]
# # Load DataFrames into Database

# %%
#Reset index name to load into SQL database
clean_new_york_tree_census_2015_df.index.name = "id"

# %%
updated_tree_census_data = clean_new_york_tree_census_2015_df.rename(columns={"address": "tree_address"})

# %%
updated_tree_census_data.head()
# Out:
#     tree_id  stump_diam status health                           spc_latin  \
# id
# 0    606945           0  Alive   Good              Fraxinus pennsylvanica
# 1    160321           0  Alive   Good  Gleditsia triacanthos var. inermis
# 2    541347           0  Alive   Good                    Pyrus calleryana
# 3    613930           0  Alive   Good                    Pyrus calleryana
# 4     18353           0  Alive   Good                   Prunus virginiana
#
#                 spc_common         tree_address  zipcode  boroname  \
# id
# 0                green ash    76-046 164 STREET    11366    Queens
# 1              honeylocust     72-020 32 AVENUE    11370    Queens
# 2             Callery pear   153-026 119 AVENUE    11434    Queens
# 3             Callery pear         89 89 STREET    11209  Brooklyn
# 4   'Schubert' chokecherry  559 BEACH 68 STREET    11692    Queens
#
#                     nta_name   latitude  longitude  \
# id
# 0          Kew Gardens Hills  40.724339 -73.805180
# 1            Jackson Heights  40.756626 -73.894167
# 2               Baisley Park  40.679777 -73.788463
# 3                  Bay Ridge  40.622743 -74.037543
# 4   Hammels-Arverne-Edgemere  40.596514 -73.797622
#
#                 spc_latin_for_join
# id
# 0            fraxinuspennsylvanica
# 1   gleditsiatriacanthosvarinermis
# 2                  pyruscalleryana
# 3                  pyruscalleryana
# 4                 prunusvirginiana

# %%
updated_tree_census_data.to_sql(name='new_york_tree_census_data_final', con=engine, if_exists='append', index=True)

# %%
#IT RAN!
